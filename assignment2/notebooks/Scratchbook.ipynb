# %% [markdown]
# # This was used as a scratch-book, you don't need this if you're reviewing our assignment

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.arima_model import ARMA
import statsmodels.api as sm

train = pd.read_csv('../data/training_1.csv')
train2 = pd.read_csv('../data/training_2.csv')

# %%
res = sm.tsa.arma_order_select_ic(train['L_T3'], ic=['aic'], max_ma=4)
res.aic_min_order

# %%
signal = 'L_T7'

plt.plot(train2[signal][1500:2000])

# %%
train2['DATETIME_time'] = pd.to_datetime(train2['DATETIME'],format='%d/%m/%y %H')

# %%
train2['DATETIME2_comp'] = train2['DATETIME']

# %%
train2.head()
# Out:
#       DATETIME  L_T1  L_T2  L_T3  L_T4  L_T5  L_T6  L_T7  F_PU1  S_PU1  \
# 0  04/07/16 00  2.44  5.24  3.19  4.10  2.86  5.50  4.39  93.63    1.0
# 1  04/07/16 01  2.66  4.53  3.20  4.18  3.29  5.44  4.53  89.41    1.0
# 2  04/07/16 02  3.11  3.66  3.66  4.21  3.87  5.15  3.22  89.88    1.0
# 3  04/07/16 03  3.62  3.04  4.17  4.04  3.56  4.98  2.40  88.10    1.0
# 4  04/07/16 04  4.08  2.68  4.73  3.20  3.11  5.39  3.46  87.01    1.0
#
#           ...          P_J302  P_J306  P_J307  P_J317  P_J14  P_J422  \
# 0         ...           21.69   82.72   21.58   71.99  39.33   29.64
# 1         ...           29.81   86.62   29.81   59.76  42.17   26.15
# 2         ...           29.85   87.64   29.85   58.50  42.00   25.56
# 3         ...           31.60   64.25   31.47   72.30  43.24   28.38
# 4         ...           32.30   64.23   32.17   72.53  44.00   28.04
#
#    ATT_FLAG           DATETIME2  DATETIME2_comp           DATETIME3
# ...

# %%
import datetime

# train2[train2['DATETIME'] > datetime.date(2016, 9, 13)]
gt = train2[train2['DATETIME_time'] >= '2016-12-06 07']
gt[gt['DATETIME_time'] <= '2016-12-10 04']
# Out:
#          DATETIME  L_T1  L_T2  L_T3  L_T4  L_T5  L_T6  L_T7   F_PU1  S_PU1  \
# 3727  06/12/16 07  4.00  3.54  4.62  4.25  3.77  5.50  4.20   93.95    1.0
# 3728  06/12/16 08  4.04  3.98  4.35  3.99  3.92  5.42  4.43   95.12    1.0
# 3729  06/12/16 09  4.17  4.54  3.90  3.07  3.31  5.03  2.65   94.54    1.0
# 3730  06/12/16 10  4.17  5.08  3.50  3.16  2.46  5.26  2.93   95.08    1.0
# 3731  06/12/16 11  4.15  5.38  3.07  3.29  1.60  5.50  3.38   94.63    1.0
# 3732  06/12/16 12  4.06  5.42  3.42  3.32  1.95  5.50  3.83   95.39    1.0
# 3733  06/12/16 13  3.91  5.34  3.86  3.20  2.51  5.50  4.71   96.01    1.0
# 3734  06/12/16 14  3.82  5.29  4.41  3.15  2.92  5.22  3.51   95.49    1.0
# 3735  06/12/16 15  3.75  5.23  4.90  3.20  3.48  4.96  2.19   95.45    1.0
# 3736  06/12/16 16  3.63  5.23  5.24  3.33  3.97  5.07  2.05   95.08    1.0
# 3737  06/12/16 17  3.86  5.48  4.90  3.26  3.29  5.31  2.37   90.13    1.0
# ...
